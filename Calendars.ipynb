# %%
import gflags
import httplib2

from apiclient.discovery import build
from oauth2client.file import Storage
from oauth2client.client import OAuth2WebServerFlow
from oauth2client.tools import run

from pprint import pprint

FLAGS = gflags.FLAGS

# Set up a Flow object to be used if we need to authenticate. This
# sample uses OAuth 2.0, and we set up the OAuth2WebServerFlow with
# the information it needs to authenticate. Note that it is called
# the Web Server Flow, but it can also handle the flow for native
# applications
# The client_id and client_secret can be found in Google Developers Console
FLOW = OAuth2WebServerFlow(
    client_id='682738649183-fc1umbtoesi8l7vjga6aj2fud88v2pqr.apps.googleusercontent.com',
    client_secret='21rU-EgtkJnGwK0fQfsm9UMA',
    scope='https://www.googleapis.com/auth/calendar',
    user_agent='test')

# To disable the local server feature, uncomment the following line:
# FLAGS.auth_local_webserver = False

# If the Credentials don't exist or are invalid, run through the native client
# flow. The Storage object will ensure that if successful the good
# Credentials will get written back to a file.
storage = Storage('calendar.dat')
credentials = storage.get()
if credentials is None or credentials.invalid == True:
  credentials = run(FLOW, storage)

# Create an httplib2.Http object to handle our HTTP requests and authorize it
# with our good Credentials.
http = httplib2.Http()
http = credentials.authorize(http)

# Build a service object for interacting with the API. Visit
# the Google Developers Console
# to get a developerKey for your own application.
service = build(serviceName='calendar', version='v3', http=http,
       developerKey='AIzaSyCEovF8jO_N68EUmI_H0EbGYeIxACvYGRA')
       
#boucler sur les calendries pour récuperer les ids
calList = []
       
page_token = None
while True:
  calendar_list = service.calendarList().list(pageToken=page_token).execute()
  for calendar_list_entry in calendar_list['items']:
    if "PAR-OPE" in calendar_list_entry['summary']:
        calList.append(calendar_list_entry)
  page_token = calendar_list.get('nextPageToken')
  if not page_token:
    break

calIds = [x['id'] for x in calList]

calendar = service.calendars().get(calendarId=calIds[0]).execute()

#boucler sur un calendrier afficher ses events

creators = []

page_token = None
while True:
  events = service.events().list(calendarId=calIds[0], pageToken=page_token).execute()
  for event in events['items']:
    try:
        event["creator"]
        creators.append(event["creator"]["email"])
        pprint(event["creator"]["email"])
    except KeyError:
        try:
            event["organizer"]
            creators.append(event["organizer"]["email"])
        except KeyError:
            print "error"
  page_token = events.get('nextPageToken')
  if not page_token:
    break
# Out:
# u'hugo@fifty-five.com'
# u'francois@fifty-five.com'
# u'francois@fifty-five.com'
# u'francois@fifty-five.com'
# u'antoine.lenotre@fifty-five.com'
# u'antoine.lenotre@fifty-five.com'
# u'francois@fifty-five.com'
# u'serge@fifty-five.com'
# u'jean@fifty-five.com'
# u'jean-francois@fifty-five.com'
# u'antoine.lenotre@fifty-five.com'
# u'kimtran@fifty-five.com'
# u'denis@fifty-five.com'
# u'antoine@fifty-five.com'
# u'nicolas@fifty-five.com'
# u'nicolas@fifty-five.com'
# u'kimtran@fifty-five.com'
# u'arnaud@fifty-five.com'
# u'adrien@fifty-five.com'
# u'adrien@fifty-five.com'
# u'kimtran@fifty-five.com'
# u'laurent.meyer@fifty-five.com'
# u'laurent.meyer@fifty-five.com'
# u'laurent.meyer@fifty-five.com'
# u'jean@fifty-five.com'
# u'kimtran@fifty-five.com'
# u'louise-anne@fifty-five.com'
# u'laurent.senesi@fifty-five.com'
# u'francois@fifty-five.com'
# u'denis@fifty-five.com'
# u'laurent.meyer@fifty-five.com'
# u'adrien@fifty-five.com'
# u'antoine.lenotre@fifty-five.com'
# ...

# %%
crea = pd.DataFrame(creators)

crea.to_csv("creators")
